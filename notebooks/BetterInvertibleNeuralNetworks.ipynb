# %% [markdown]
# # The Idea
#
# Firstly, we change the architecture.
# Secondly, we create new layer.

# %%
import jax 
import jax.numpy as np
import jax.scipy as sp
from jax import value_and_grad, grad, jit, vmap
from jax.example_libraries import optimizers
import numpy as onp
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm, trange

plt.style.use('dark_background')
background_color = tuple(onp.array([66, 68, 69])/255)
plt.rcParams['axes.facecolor'] = background_color
plt.rcParams['figure.facecolor'] = background_color

# %%
# class ParametricFunction:
#     def __init__(self, init_func, forward_func):
#         self.init_func = init_func
#         self.forward_func = forward_func
#     def init(self, key):
#         self.params = self.init_func(key)
#     def forward(self, X):
#         return self.forward_func(self.params, X)
#     def __add__(self, other):
#         def init_func(key):
#             k0, k1 = jax.random.split(key)
#             return (self.init_func(k0), other.init_func(k1))
#         def forward_func(params, X):
#             X = self.forward_func(self.params, X)
#             X = other.forward_func(other.forward_func, X)
#             return X
#         return ParametricFunction(init_func, forward_func)

# %%
def Dense(input_dim, output_dim, activation_function):
    def init(key):
        weight = jax.random.normal(key, shape=(input_dim, output_dim))/input_dim # /output_dim
        bias = np.zeros((output_dim,))
        return weight, bias
    def forward(params, X):
        weight, bias = params
        return activation_function(X @ weight + bias)
    return init, forward

# %%
def Sequential(*args):
    inits, forwards = zip(*args)
    def init(key):
        return [
            init(key)
            for init, key in zip(
                inits, 
                jax.random.split(key, len(inits))
            )
        ]
    def forward(params, X):
        for forward, params in zip(forwards, params):
            X = forward(params, X)
        return X
    return init, forward

# %%
def Residual(layer):
    init, forward = layer
    def residual_forward(params, X):
        return forward(params, X) + X
    return init, residual_forward

# %%
def ExpandSqueeze(inout_dim, hidden_dim, activation_function=lambda x: x):
    return Residual(Sequential(
        Dense(inout_dim, hidden_dim, jax.nn.relu),
        Dense(hidden_dim, hidden_dim, jax.nn.relu),
        Dense(hidden_dim, inout_dim, lambda x: x),
    ))

# %%
def es_constraint(params):
    (w0, _), (w1, _), (w2, _) = params
    return (
        jax.nn.relu(np.linalg.norm(w0, ord=2) - 0.95) +
        jax.nn.relu(np.linalg.norm(w1, ord=2) - 0.95) +
        jax.nn.relu(np.linalg.norm(w2, ord=2) - 0.95)
    ) 
    
def constraint(params):
    return sum(es_constraint(p) for p in params)

def log_density(params, X):
    
    Z, pullback = jax.vjp(lambda X: forward(params, X), X)
    
    basis = np.eye(Z.shape[1], dtype=Z.dtype)[:,np.newaxis,:].repeat(Z.shape[0], axis=1)
    jac = vmap(pullback)(basis)[0].transpose((1,0,2))
    
    return sp.stats.norm.logpdf(Z).sum(axis=1) + np.log(np.abs(jax.vmap(np.linalg.det)(jac)))

def loss(params, X, C):
    weights = [p[0] for p in params]
    return -log_density(params, X).sum() + C*constraint(params)

# %%
def sample_data(key, n, s=0.0):
    R = jax.random.normal(key, shape=(n, 3))
    return (R[:, 0].reshape(-1,1) + 3) * np.c_[np.sin(1*R[:,0]), np.cos(1*R[:,0])] + s*R[:, 1:]

# %%
key = jax.random.PRNGKey(1022023)
X = sample_data(key, 1000, 0.2)

# %%
plt.scatter(X[:,0], X[:,1])

# %%
n = 16
init, forward = Sequential(
    ExpandSqueeze(2, n),
    ExpandSqueeze(2, n),
    ExpandSqueeze(2, n),
    ExpandSqueeze(2, n),
    ExpandSqueeze(2, n),
    ExpandSqueeze(2, n),
    ExpandSqueeze(2, n),
    ExpandSqueeze(2, n),
)

# %%
key = jax.random.PRNGKey(5022023)
params = init(key)
losses = []

# %%
params = get_params(opt_state)
learning_rate=0.001
opt_init, opt_update, get_params = optimizers.adam(learning_rate)
opt_state = opt_init(params)

# %%
key = jax.random.PRNGKey(1022023)
EPOCHS = 10000
batch_size = 128 * 8
C = 1000.5
jitvgloss = jit(lambda params: jax.value_and_grad(lambda params: loss(params, X, C))(params))

for epoch in (pbar := trange(EPOCHS)):
    
    key, subkey = jax.random.split(key)
    X = sample_data(subkey, batch_size, 0.2)
    value, grads = jitvgloss(get_params(opt_state))
    opt_state = opt_update(epoch, grads, opt_state)
    
    losses.append(value)
    pbar.set_description(f"{value:0.03f}")
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1352], line 7
#       4 C = 1000.5
#       5 jitvgloss = jit(lambda params: jax.value_and_grad(lambda params: loss(params, X, C))(params))
# ----> 7 for epoch in (pbar := trange(EPOCHS)):
#       9     key, subkey = jax.random.split(key)
#      10     X = sample_data(subkey, batch_size, 0.2)
#
# File ~/.local/lib/python3.10/site-packages/tqdm/notebook.py:259, in tqdm_notebook.__iter__(self)
#     257 try:
#     258     it = super(tqdm_notebook, self).__iter__()
# --> 259     for obj in it:
#     260         # return super(tqdm...) will not catch exception
#     261         yield obj
#     262 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File ~/.local/lib/python3.10/site-packages/tqdm/std.py:1205, in tqdm.__iter__(self)
#    1203 dt = cur_t - last_print_t
#    1204 if dt >= mininterval and cur_t >= min_start_t:
# -> 1205     self.update(n - last_print_n)
#    1206     last_print_n = self.last_print_n
#    1207     last_print_t = self.last_print_t
#
# File ~/.local/lib/python3.10/site-packages/tqdm/notebook.py:271, in tqdm_notebook.update(self, n)
#     269 def update(self, n=1):
#     270     try:
# --> 271         return super(tqdm_notebook, self).update(n=n)
#     272     # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#     273     except:  # NOQA
#     274         # cannot catch KeyboardInterrupt when using manual tqdm
#     275         # as the interrupt will most likely happen on another statement
#
# File ~/.local/lib/python3.10/site-packages/tqdm/std.py:1256, in tqdm.update(self, n)
#    1254     self._ema_dn(dn)
#    1255     self._ema_dt(dt)
# -> 1256 self.refresh(lock_args=self.lock_args)
#    1257 if self.dynamic_miniters:
#    1258     # If no `miniters` was specified, adjust automatically to the
#    1259     # maximum iteration rate seen so far between two prints.
#    1260     # e.g.: After running `tqdm.update(5)`, subsequent
#    1261     # calls to `tqdm.update()` will only cause an update after
#    1262     # at least 5 more iterations.
#    1263     if self.maxinterval and dt >= self.maxinterval:
#
# File ~/.local/lib/python3.10/site-packages/tqdm/std.py:1361, in tqdm.refresh(self, nolock, lock_args)
#    1359     else:
#    1360         self._lock.acquire()
# -> 1361 self.display()
#    1362 if not nolock:
#    1363     self._lock.release()
#
# File ~/.local/lib/python3.10/site-packages/tqdm/notebook.py:167, in tqdm_notebook.display(self, msg, pos, close, bar_style, check_delay)
#     164     msg = self.format_meter(**d)
#     166 ltext, pbar, rtext = self.container.children
# --> 167 pbar.value = self.n
#     169 if msg:
#     170     # html escape special characters (like '&')
#     171     if '<bar/>' in msg:
#
# File ~/.local/lib/python3.10/site-packages/traitlets/traitlets.py:732, in TraitType.__set__(self, obj, value)
#     730     raise TraitError('The "%s" trait is read-only.' % self.name)
#     731 else:
# --> 732     self.set(obj, value)
#
# File ~/.local/lib/python3.10/site-packages/traitlets/traitlets.py:721, in TraitType.set(self, obj, value)
#     717     silent = False
#     718 if silent is not True:
#     719     # we explicitly compare silent to True just in case the equality
#     720     # comparison above returns something other than True/False
# --> 721     obj._notify_trait(self.name, old_value, new_value)
#
# File ~/.local/lib/python3.10/site-packages/traitlets/traitlets.py:1505, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1504 def _notify_trait(self, name, old_value, new_value):
# -> 1505     self.notify_change(
#    1506         Bunch(
#    1507             name=name,
#    1508             old=old_value,
#    1509             new=new_value,
#    1510             owner=self,
#    1511             type="change",
#    1512         )
#    1513     )
#
# File ~/.local/lib/python3.10/site-packages/ipywidgets/widgets/widget.py:693, in Widget.notify_change(self, change)
#     689 if self.comm is not None and self.comm.kernel is not None:
#     690     # Make sure this isn't information that the front-end just sent us.
#     691     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     692         # Send new state to front-end
# --> 693         self.send_state(key=name)
#     694 super().notify_change(change)
#
# File ~/.local/lib/python3.10/site-packages/ipywidgets/widgets/widget.py:571, in Widget.send_state(self, key)
#     563 def send_state(self, key=None):
#     564     """Sends the widget state, or a piece of it, to the front-end, if it exists.
#     565
#     566     Parameters
#    (...)
#     569         A single property's name or iterable of property names to sync with the front-end.
#     570     """
# --> 571     state = self.get_state(key=key)
#     572     if len(state) > 0:
#     573         if self._property_lock:  # we need to keep this dict up to date with the front-end values
#
# File ~/.local/lib/python3.10/site-packages/ipywidgets/widgets/widget.py:605, in Widget.get_state(self, key, drop_defaults)
#     603     raise ValueError("key must be a string, an iterable of keys, or None")
#     604 state = {}
# --> 605 traits = self.traits()
#     606 for k in keys:
#     607     to_json = self.trait_metadata(k, 'to_json', self._trait_to_json)
#
# File ~/.local/lib/python3.10/site-packages/traitlets/traitlets.py:1900, in HasTraits.traits(self, **metadata)
#    1886 def traits(self, **metadata):
#    1887     """Get a ``dict`` of all the traits of this class.  The dictionary
#    1888     is keyed on the name and the values are the TraitType objects.
#    1889
#    (...)
#    1898     to the function.
#    1899     """
# -> 1900     traits = self._traits.copy()
#    1902     if len(metadata) == 0:
#    1903         return traits
#
# KeyboardInterrupt:

# %%
plt.plot(losses)

# %%
constraint(get_params(opt_state))
# Out:
# Array(0.00070757, dtype=float32)

# %%
_, g_forward = Sequential(
        Dense(1, 1, jax.nn.relu),
        Dense(1, 1, jax.nn.relu),
        Dense(1, 1, lambda x: x),
    )
def es_backward(layer, Z, n=16):
    Z_prev = Z
    for _ in range(n):
        Z_prev = Z - g_forward(layer, Z_prev)
    return Z_prev

def backward(params, Z, n=16):
    for layer in reversed(params):
        Z = es_backward(layer, Z, n)
    return Z

# %%
key = jax.random.PRNGKey(1022023)
Z = jax.random.normal(key, shape=(1000,2))

# %%
Xhat = backward(get_params(opt_state), Z, 160)
plt.scatter(Xhat[:,0], Xhat[:,1])
plt.scatter(X[:,0], X[:,1])
# plt.xlim(-6,6)
# plt.ylim(-6,6)

# %%
Zhat = forward(get_params(opt_state), X)
plt.scatter(Z[:,0], Z[:,1])
plt.scatter(Zhat[:,0], Zhat[:,1])

# %%
for p in get_params(opt_state):
    for g in p: 
        # print(np.linalg.norm(g[0], ord=2))
        pass
        # print(np.linalg.det(g[0]))
    a = p[0][0] @ p[1][0] @ p[2][0]
    print(np.linalg.norm(a, ord=2))
# Out:
# 0.8500924
# 0.70035964
# 0.7175606
# 0.45628083

# %%
_, g_forward = Sequential(
    Dense(1, 1, jax.nn.relu),
    Dense(1, 1, jax.nn.relu),
    Dense(1, 1, lambda x: x),
)
def check_lipschitz(params, X):
    Z, pullback = jax.vjp(lambda X: g_forward(params, X), X)
    
    basis = np.eye(Z.shape[1], dtype=Z.dtype)[:,np.newaxis,:].repeat(Z.shape[0], axis=1)
    jac = vmap(pullback)(basis)[0].transpose((1,0,2))
    
    return vmap(lambda x: np.linalg.norm(x, ord=2))(jac).max()

# %%
A = jax.random.normal(key, shape=(1000,2))
[check_lipschitz(p, A) for p in get_params(opt_state)]
# Out:
# [Array(0.85011584, dtype=float32),
#  Array(0.65377164, dtype=float32),
#  Array(0.7253368, dtype=float32),
#  Array(0.42178753, dtype=float32)]

# %% [markdown]
# # MNIST

# %%
import torch
import torchvision as tv

# %%
# tv.datasets.MNIST("./data", download=True)

# %%
ds = tv.datasets.MNIST("../data")
plt.imshow(np.array(ds[0][0]))

# %%
def collate_fn(batch):
    return np.c_[[np.array(x) for x, _ in batch]].reshape(-1,784).astype(np.float32) / 255 - 0.5
dl = torch.utils.data.DataLoader(ds, batch_size=32, collate_fn=collate_fn, shuffle=True)

# %%
n = 128
init, forward = Sequential(
    ExpandSqueeze(784, n),
    ExpandSqueeze(784, n),
    ExpandSqueeze(784, n),
    ExpandSqueeze(784, n),
    ExpandSqueeze(784, n),
    ExpandSqueeze(784, n),
    ExpandSqueeze(784, n),
    ExpandSqueeze(784, n),
)

# %%
key = jax.random.PRNGKey(5022023)
params = init(key)
losses = []

# %%
# params = get_params(opt_state)
learning_rate=0.001
opt_init, opt_update, get_params = optimizers.adam(learning_rate)
opt_state = opt_init(params)

# %%
key = jax.random.PRNGKey(9022023)
EPOCHS = 1
C = 1000.0
jitvgloss = jit(lambda params, X, C: jax.value_and_grad(lambda params: loss(params, X, C))(params))

for epoch in (pbar := trange(EPOCHS)):
    
    for X in dl:
        value, grads = jitvgloss(get_params(opt_state), X, C)
        opt_state = opt_update(epoch, grads, opt_state)

        losses.append(value)
        pbar.set_description(f"{value:0.03f}")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[86], line 9
#       6 for epoch in (pbar := trange(EPOCHS)):
#       8     for X in dl:
# ----> 9         value, grads = jitvgloss(get_params(opt_state), X, C)
#      10         opt_state = opt_update(epoch, grads, opt_state)
#      12         losses.append(value)
#
# KeyboardInterrupt:

# %%
plt.plot(losses)

# %%
constraint(get_params(opt_state))
# Out:
# Array(0., dtype=float32)

# %%
_, g_forward = Sequential(
        Dense(1, 1, jax.nn.relu),
        Dense(1, 1, jax.nn.relu),
        Dense(1, 1, lambda x: x),
    )
def es_backward(layer, Z, n=16):
    Z_prev = Z
    for _ in range(n):
        Z_prev = Z - g_forward(layer, Z_prev)
    return Z_prev

def backward(params, Z, n=16):
    for layer in reversed(params):
        Z = es_backward(layer, Z, n)
    return Z

# %%
key = jax.random.PRNGKey(1022023)
Z = jax.random.normal(key, shape=(8,784))

# %%
Xhat = backward(get_params(opt_state), Z, 16)

# %%
Zhat = forward(get_params(opt_state), X)

# %%
plt.imshow(X[0, :].reshape(28,28))

# %%
plt.imshow(Zhat[0, :].reshape(28,28))

# %%
plt.imshow(Xhat[0, :].reshape(28,28))

# %%
import pickle

# %%
with open('model.pickle', 'wb') as f:
    pickle.dump(get_params(opt_state), f)

# %%
with open('model.pickle', 'rb') as f:
    par = pickle.load(f)
